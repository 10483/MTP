# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from Finite_volume_method_1D import *

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Computer Modern",
    "figure.dpi": 100,
})

# %%
chippath = '../../DataKian/Al_LT165chip7/'
Al_data = KID_data(chippath,
                   lambda_ph_in_nm=673,
                   KIDno=2,
                   readout_power=93,
                   temp_in_mK=120,
                   length=310,
                   T_eff=0.200,
                   N0=172e8,
                   sigma_IC=5,
                   D=15000)

chippath = '../../DataKian/bTa_LT278W2chip5/'
bTa_data = KID_data(chippath,
                    lambda_ph_in_nm=673,
                    KIDno=3,
                    readout_power=96,
                    temp_in_mK=100,
                    length=90,
                    T_eff=0.100,
                    N0=303e8,
                    sigma_IC=5,
                    D=50)

# %%
bTa_data.fit_tail(start=175,end=200)
Al_data.fit_tail(start=500)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bTa_data.eta_pb
# Out:
# 0.575611085729339

# %%
Al_data.eta_pb
# Out:
# 0.8150991070542876

# %%
bTa_sim=KID_sim(bTa_data,0.01,1/4,100)
Al_sim=KID_sim(Al_data,0.01,1/4,100)
# Out:
# 100%|██████████| 10000/10000 [00:33<00:00, 296.98it/s]
# 100%|██████████| 10000/10000 [02:17<00:00, 72.75it/s]

# %%
compbTa = sim_data_comp(bTa_data,bTa_sim)
compAl = sim_data_comp(Al_data,Al_sim)
print(bTa_data.eta_pb)
print(Al_data.eta_pb)
plt.figure()
plt.semilogy(compbTa.t_full,compbTa.Nqp_phase_data)
#plt.semilogy(compbTa.t_full,bTa_data.phase)
#plt.semilogy(compbTa.t_full,compbTa.Nqp_amp_data)
plt.plot(compbTa.t_sim_aligned,compbTa.Nqp_sim)
plt.show()
plt.figure()
plt.semilogy(compAl.t_full,compAl.Nqp_phase_data)
#plt.semilogy(compAl.t_full,compAl.Nqp_amp_data)
plt.semilogy(compAl.t_sim_aligned,compAl.Nqp_sim)
plt.show()
# Out:
# 0.575611085729339
# 0.8150991070542876
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bTa_data.Rprime/bTa_data.dthetadN
# Out:
# 312.9568539533944

# %%
Al_data.Rprime/Al_data.dthetadN
# Out:
# 3.1043673463667307
