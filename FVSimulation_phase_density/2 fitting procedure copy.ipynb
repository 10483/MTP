# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib widget
from joblib import Parallel, delayed
from scipy.optimize import curve_fit
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Computer Modern",
    "figure.dpi": 100
})



from Finite_volume_method_1D import *

# %%
chippath = '../../DataKian/bTa_LT278W2chip5/'
filename = 'KID3_96dBm__TmK20_avgpulse_ampphase.csv'
length = 90
simtime = 300
dtinit=0.001
dxfrac=1/4

lambdasinnm = [402,673,986,1545]

KIDdict = {}
for lambdanm in lambdasinnm:
    KIDdict[lambdanm] = KID_data(chippath,lambdanm,filename,length)
    KIDdict[lambdanm].fit_tail(showplots=False)
for lambdanm in lambdasinnm:
    KIDdict[lambdanm] = KID_data(chippath,lambdanm,filename,length)
    KIDdict[lambdanm].fit_tail(start=200,showplots=False)

# %%
Ls=[]
for lambdanm in lambdasinnm:
    print(KIDdict[lambdanm].tauqpstar,KIDdict[lambdanm].tauqpstarstd)
    print(KIDdict[lambdanm].L)
    Ls.append(KIDdict[lambdanm].L)
L=np.mean(Ls) # use the same linear decay rate for all wavelengths
# Out:
# 194.88850185176454 2.2767849027049727
# 0.005131139038467322
# 201.89787714954562 3.9613091250212302
# 0.004952999081111193
# 191.8028632586559 3.097737438872922
# 0.005213686506084371
# 190.54199588046978 6.5199494193543215
# 0.0052481868649435

# %%
def prep_data(neg_offset):
    ylist = []
    for lambdanm in lambdasinnm:
        xfit = np.arange(neg_offset,neg_offset+simtime-KIDdict[lambdanm].dt/2,KIDdict[lambdanm].dt)
        indmin = np.argmax(KIDdict[lambdanm].phase)+neg_offset
        indmax = indmin + simtime
        ylist.append(KIDdict[lambdanm].phase[indmin:indmax])
    yfit = np.array(ylist).ravel()
    return xfit, yfit

def func_to_parallelize(t,params):
     SIM = KID_sim(params,dtinit,dxfrac,simtime_approx=simtime,D_const=False)
     return np.interp(t,SIM.t_axis_interp,SIM.phaseintime)

def fitfunc(t,eta,sigma,tau,Q0):
    print('eta (-):\t',eta)
    print('sigma (um):\t',sigma)
    print('tau (us):\t',tau)
    print('Q0 (um-1):\t',Q0)
    datalist = Parallel(n_jobs=len(lambdasinnm))(delayed(func_to_parallelize)(t,KID_params(eta_pb=eta,sigma_IC=sigma,trickle_time=tau,Q0=Q0,KID=KIDdict[lambdanm],L=L)) for lambdanm in lambdasinnm)
    return np.concatenate(datalist)

def par_func_plot(params):
     SIM = KID_sim(params,dtinit,dxfrac,simtime_approx=simtime,D_const=False)
     return SIM

def plotsim(eta,sigma,tau,Q0):
    datalist = Parallel(n_jobs=4)(delayed(par_func_plot)(KID_params(eta_pb=eta,sigma_IC=sigma,trickle_time=tau,Q0=Q0,KID=KIDdict[lambdanm],L=L)) for lambdanm in lambdasinnm)
    plotdata = {}
    for obj,lambdanm in zip(datalist,lambdasinnm):
         plotdata[lambdanm]=obj
    return plotdata

# %%
xfit,yfit=prep_data(-10) #e.g. -5 means take 5 data points before the max into account for the data
popt, pcov = curve_fit(fitfunc,xfit,yfit,p0=[0.59,1,3,0.5],bounds=[[0.01,0.5,0.01,0.1],[1,length/6,10,np.inf]])
print('Done!')
# Out:
# eta (-):	 0.59
# sigma (um):	 1.0
# tau (us):	 3.0
# Q0 (um-1):	 0.5
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9177	Simtime (us): 300.08123788479184
# Iteration: 10963	Simtime (us): 300.00517254020906
# Iteration: 12427	Simtime (us): 300.09919737513625
# Iteration: 14321	Simtime (us): 300.02760224279825
# eta (-):	 0.5900000149011612
# sigma (um):	 1.0
# tau (us):	 3.0
# Q0 (um-1):	 0.5
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9177	Simtime (us): 300.08290551520163
# Iteration: 10963	Simtime (us): 300.00517795661335
# Iteration: 12427	Simtime (us): 300.09923043907886
# Iteration: 14321	Simtime (us): 300.02758047155264
# eta (-):	 0.59
# sigma (um):	 1.0000000149011612
# tau (us):	 3.0
# Q0 (um-1):	 0.5
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9177	Simtime (us): 300.08122301412556
# Iteration: 10963	Simtime (us): 300.00517216851216
# Iteration: 12427	Simtime (us): 300.09919685055235
# Iteration: 14321	Simtime (us): 300.02760222991834
# eta (-):	 0.59
# sigma (um):	 1.0
# tau (us):	 3.0000000447034836
# Q0 (um-1):	 0.5
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9177	Simtime (us): 300.07946271499065
# Iteration: 10963	Simtime (us): 300.00516870351645
# Iteration: 12427	Simtime (us): 300.09916075666224
# Iteration: 14321	Simtime (us): 300.02763266072805
# eta (-):	 0.59
# sigma (um):	 1.0
# tau (us):	 3.0
# Q0 (um-1):	 0.5000000149011612
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9177	Simtime (us): 300.07922682988797
# Iteration: 10963	Simtime (us): 300.00516612491146
# Iteration: 12427	Simtime (us): 300.09915762797146
# Iteration: 14321	Simtime (us): 300.02762856652513
# eta (-):	 0.6427046035299689
# sigma (um):	 1.867099327161978
# tau (us):	 2.334033096846901
# Q0 (um-1):	 0.7555626302559173
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9102	Simtime (us): 300.04207121928505
# Iteration: 10797	Simtime (us): 300.03261040059573
# Iteration: 12199	Simtime (us): 300.07946428734454
# Iteration: 13977	Simtime (us): 300.04164382682735
# eta (-):	 0.6427046184311301
# sigma (um):	 1.867099327161978
# tau (us):	 2.334033096846901
# Q0 (um-1):	 0.7555626302559173
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9102	Simtime (us): 300.04168745484844
# Iteration: 10797	Simtime (us): 300.03276260922354
# Iteration: 12199	Simtime (us): 300.07944008058297
# Iteration: 13977	Simtime (us): 300.04168309810075
# eta (-):	 0.6427046035299689
# sigma (um):	 1.867099354983926
# tau (us):	 2.334033096846901
# Q0 (um-1):	 0.7555626302559173
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9102	Simtime (us): 300.04208983311417
# Iteration: 10797	Simtime (us): 300.03260387078835
# Iteration: 12199	Simtime (us): 300.07946530462056
# Iteration: 13977	Simtime (us): 300.04164245694044
# eta (-):	 0.6427046035299689
# sigma (um):	 1.867099327161978
# tau (us):	 2.3340331316267044
# Q0 (um-1):	 0.7555626302559173
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9102	Simtime (us): 300.04253836415774
# Iteration: 10797	Simtime (us): 300.03241491685785
# Iteration: 12199	Simtime (us): 300.07950068823316
# Iteration: 13977	Simtime (us): 300.04158711709536
# eta (-):	 0.6427046035299689
# sigma (um):	 1.867099327161978
# tau (us):	 2.334033096846901
# Q0 (um-1):	 0.7555626451570785
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 9102	Simtime (us): 300.04240495231136
# Iteration: 10797	Simtime (us): 300.03247826102785
# Iteration: 12199	Simtime (us): 300.07948537559834
# Iteration: 13977	Simtime (us): 300.04160979450836
# eta (-):	 0.7373354056696686
# sigma (um):	 9.11842431667461
# tau (us):	 1.750173972368564
# Q0 (um-1):	 0.6853740512237848
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 8027	Simtime (us): 300.02914759063654
# Iteration: 9444	Simtime (us): 300.04322507906147
# Iteration: 10550	Simtime (us): 300.03245965868445
# Iteration: 12093	Simtime (us): 300.08390511163236
# eta (-):	 0.7373354205708298
# sigma (um):	 9.11842431667461
# tau (us):	 1.750173972368564
# Q0 (um-1):	 0.6853740512237848
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 8027	Simtime (us): 300.02921200674587
# Iteration: 9444	Simtime (us): 300.04321435877375
# Iteration: 10550	Simtime (us): 300.03503902831534
# Iteration: 12093	Simtime (us): 300.08390032701794
# eta (-):	 0.7373354056696686
# sigma (um):	 9.11842445254972
# tau (us):	 1.750173972368564
# Q0 (um-1):	 0.6853740512237848
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 8027	Simtime (us): 300.02911576362914
# Iteration: 9444	Simtime (us): 300.04323322660692
# Iteration: 10550	Simtime (us): 300.03118410319524
# Iteration: 12093	Simtime (us): 300.08390924981744
# eta (-):	 0.7373354056696686
# sigma (um):	 9.11842431667461
# tau (us):	 1.7501739984481886
# Q0 (um-1):	 0.6853740512237848
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 8027	Simtime (us): 300.02905617060354
# Iteration: 9444	Simtime (us): 300.04324595385186
# Iteration: 10550	Simtime (us): 300.02799204419915
# Iteration: 12093	Simtime (us): 300.08391891386414
# eta (-):	 0.7373354056696686
# sigma (um):	 9.11842431667461
# tau (us):	 1.750173972368564
# Q0 (um-1):	 0.685374066124946
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 8027	Simtime (us): 300.02907789243375
# Iteration: 9444	Simtime (us): 300.04323670933894
# Iteration: 10550	Simtime (us): 300.02966640955827
# Iteration: 12093	Simtime (us): 300.08391031868445
# eta (-):	 0.7904848311812139
# sigma (um):	 11.34929493536067
# tau (us):	 1.6403249186749644
# Q0 (um-1):	 0.6469991203759223
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7563	Simtime (us): 300.00244406331186
# Iteration: 8987	Simtime (us): 300.02256856693026
# Iteration: 10097	Simtime (us): 300.14813908442363
# Iteration: 11512	Simtime (us): 300.10127399428827
# eta (-):	 0.7904848460823751
# sigma (um):	 11.34929493536067
# tau (us):	 1.6403249186749644
# Q0 (um-1):	 0.6469991203759223
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7564	Simtime (us): 300.22805104960766
# Iteration: 8987	Simtime (us): 300.02266450792356
# Iteration: 10097	Simtime (us): 300.14820406421945
# Iteration: 11512	Simtime (us): 300.10129653457045
# eta (-):	 0.7904848311812139
# sigma (um):	 11.349295104478342
# tau (us):	 1.6403249186749644
# Q0 (um-1):	 0.6469991203759223
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7563	Simtime (us): 300.00635120208895
# Iteration: 8987	Simtime (us): 300.02251214122265
# Iteration: 10097	Simtime (us): 300.14810264590297
# Iteration: 11512	Simtime (us): 300.10126323363546
# eta (-):	 0.7904848311812139
# sigma (um):	 11.34929493536067
# tau (us):	 1.6403249431177105
# Q0 (um-1):	 0.6469991203759223
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7563	Simtime (us): 300.01214241712633
# Iteration: 8987	Simtime (us): 300.02240456462243
# Iteration: 10097	Simtime (us): 300.14802034744253
# Iteration: 11512	Simtime (us): 300.10123147544535
# eta (-):	 0.7904848311812139
# sigma (um):	 11.34929493536067
# tau (us):	 1.6403249186749644
# Q0 (um-1):	 0.6469991352770835
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7563	Simtime (us): 300.00989527402446
# Iteration: 8987	Simtime (us): 300.02245082925888
# Iteration: 10097	Simtime (us): 300.14805931631186
# Iteration: 11512	Simtime (us): 300.10124632053646
# eta (-):	 0.8544500997645395
# sigma (um):	 11.85425878750515
# tau (us):	 1.8182378082001271
# Q0 (um-1):	 0.5687294978281289
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7587	Simtime (us): 300.14929301403845
# Iteration: 8589	Simtime (us): 300.10363499552716
# Iteration: 10046	Simtime (us): 300.14122693475564
# Iteration: 11479	Simtime (us): 300.07759732823913
# eta (-):	 0.8544501146657006
# sigma (um):	 11.85425878750515
# tau (us):	 1.8182378082001271
# Q0 (um-1):	 0.5687294978281289
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7587	Simtime (us): 300.14939607433246
# Iteration: 8589	Simtime (us): 300.15317227105755
# Iteration: 10046	Simtime (us): 300.14121231633985
# Iteration: 11479	Simtime (us): 300.07759994041015
# eta (-):	 0.8544500997645395
# sigma (um):	 11.854258964147371
# tau (us):	 1.8182378082001271
# Q0 (um-1):	 0.5687294978281289
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7587	Simtime (us): 300.14922451346735
# Iteration: 8589	Simtime (us): 300.07004075670943
# Iteration: 10046	Simtime (us): 300.14123963377233
# Iteration: 11479	Simtime (us): 300.07759821460317
# eta (-):	 0.8544500997645395
# sigma (um):	 11.85425878750515
# tau (us):	 1.8182378352939819
# Q0 (um-1):	 0.5687294978281289
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7587	Simtime (us): 300.14912528463954
# Iteration: 8589	Simtime (us): 300.01530559092192
# Iteration: 10046	Simtime (us): 300.14125949169556
# Iteration: 11419	Simtime (us): 292.61054847658757eta (-):	 0.8544500997645395
# sigma (um):	 11.85425878750515
# tau (us):	 1.8182378082001271
# Q0 (um-1):	 0.5687295127292901
# Iteration: 11479	Simtime (us): 300.07759645245255
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7587	Simtime (us): 300.14913761358833
# Iteration: 8589	Simtime (us): 300.02910655154426
# Iteration: 10046	Simtime (us): 300.14124902350505
# Iteration: 11479	Simtime (us): 300.07759340339773
# eta (-):	 0.870493699555679
# sigma (um):	 11.877941483091695
# tau (us):	 1.820181295303834
# Q0 (um-1):	 0.5775022408198209
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7590	Simtime (us): 300.22067877595254
# Iteration: 8929	Simtime (us): 300.05925637277164
# Iteration: 10018	Simtime (us): 300.11996072023275
# Iteration: 11438	Simtime (us): 300.11986278078747
# eta (-):	 0.8704937144568402
# sigma (um):	 11.877941483091695
# tau (us):	 1.820181295303834
# Q0 (um-1):	 0.5775022408198209
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7590	Simtime (us): 300.22070494936827
# Iteration: 8929	Simtime (us): 300.05929701007475
# Iteration: 10018	Simtime (us): 300.12066228773654
# Iteration: 11438	Simtime (us): 300.12093392310473
# eta (-):	 0.870493699555679
# sigma (um):	 11.877941660086815
# tau (us):	 1.820181295303834
# Q0 (um-1):	 0.5775022408198209
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7590	Simtime (us): 300.22066394429463
# Iteration: 8929	Simtime (us): 300.05923157486626
# Iteration: 10018	Simtime (us): 300.11948982511276
# Iteration: 11438	Simtime (us): 300.11916647313874
# eta (-):	 0.870493699555679
# sigma (um):	 11.877941483091695
# tau (us):	 1.820181322426649
# Q0 (um-1):	 0.5775022408198209
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7590	Simtime (us): 300.22063737108647
# Iteration: 8929	Simtime (us): 300.05918538077213
# Iteration: 10018	Simtime (us): 300.11857889227275
# Iteration: 11438	Simtime (us): 300.11753040363836
# eta (-):	 0.870493699555679
# sigma (um):	 11.877941483091695
# tau (us):	 1.820181295303834
# Q0 (um-1):	 0.5775022557209821
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7590	Simtime (us): 300.22063919165216
# Iteration: 8929	Simtime (us): 300.05919487631057
# Iteration: 10018	Simtime (us): 300.11889860404585
# Iteration: 11438	Simtime (us): 300.11824061421477
# eta (-):	 0.8710116310510413
# sigma (um):	 11.87699476402623
# tau (us):	 1.8139093176742078
# Q0 (um-1):	 0.5751946719907095
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7566	Simtime (us): 300.20570927089125
# Iteration: 8898	Simtime (us): 300.06132214087523
# Iteration: 10004	Simtime (us): 300.09236863105145
# Iteration: 11441	Simtime (us): 300.04164076296513
# eta (-):	 0.8710116459522025
# sigma (um):	 11.87699476402623
# tau (us):	 1.8139093176742078
# Q0 (um-1):	 0.5751946719907095
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7566	Simtime (us): 300.20571464084141
# Iteration: 8898	Simtime (us): 300.06124754071766
# Iteration: 10004	Simtime (us): 300.09251752310996
# Iteration: 11280	Simtime (us): 280.39975861264246eta (-):	 0.8710116310510413
# sigma (um):	 11.876994941007244
# tau (us):	 1.8139093176742078
# Q0 (um-1):	 0.5751946719907095
# Iteration: 11441	Simtime (us): 300.04165185588045
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7566	Simtime (us): 300.20570933559955
# Iteration: 8898	Simtime (us): 300.06137737522758
# Iteration: 10004	Simtime (us): 300.09227091762727
# Iteration: 11274	Simtime (us): 279.69723292582967eta (-):	 0.8710116310510413
# sigma (um):	 11.87699476402623
# tau (us):	 1.813909344703563
# Q0 (um-1):	 0.5751946719907095
# Iteration: 11441	Simtime (us): 300.04163608234897
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7566	Simtime (us): 300.20570289725165
# Iteration: 8898	Simtime (us): 300.06146272742394
# Iteration: 10004	Simtime (us): 300.0920785309582
# Iteration: 11007	Simtime (us): 250.38458746207297eta (-):	 0.8710116310510413
# sigma (um):	 11.87699476402623
# tau (us):	 1.8139093176742078
# Q0 (um-1):	 0.5751946868918707
# Iteration: 11441	Simtime (us): 300.04162127086107
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7566	Simtime (us): 300.20570112738284
# Iteration: 8898	Simtime (us): 300.06143563177534
# Iteration: 10004	Simtime (us): 300.09214216458014
# Iteration: 11441	Simtime (us): 300.04162389834494
# eta (-):	 0.871716693430576
# sigma (um):	 11.87720379991368
# tau (us):	 1.808009294030335
# Q0 (um-1):	 0.5728198916024546
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7466	Simtime (us): 300.01283946641547
# Iteration: 8874	Simtime (us): 300.02098725241583
# Iteration: 9980	Simtime (us): 300.10907139422087
# Iteration: 11392	Simtime (us): 300.09097033163714
# eta (-):	 0.8717167083317372
# sigma (um):	 11.87720379991368
# tau (us):	 1.808009294030335
# Q0 (um-1):	 0.5728198916024546
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7466	Simtime (us): 300.00803295871966
# Iteration: 8874	Simtime (us): 300.02099652988244
# Iteration: 9980	Simtime (us): 300.10909949866756
# Iteration: 11392	Simtime (us): 300.09070433303246
# eta (-):	 0.871716693430576
# sigma (um):	 11.877203976897809
# tau (us):	 1.808009294030335
# Q0 (um-1):	 0.5728198916024546
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7466	Simtime (us): 300.01629551354525
# Iteration: 8874	Simtime (us): 300.02098420504826
# Iteration: 9980	Simtime (us): 300.10905537421382
# Iteration: 10384	Simtime (us): 197.97591804086196eta (-):	 0.871716693430576
# sigma (um):	 11.87720379991368
# tau (us):	 1.808009320971773
# Q0 (um-1):	 0.5728198916024546
# Iteration: 11392	Simtime (us): 300.09114712602636
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7466	Simtime (us): 300.02094787192376
# Iteration: 8874	Simtime (us): 300.02097380930427
# Iteration: 9980	Simtime (us): 300.10902000341981
# Iteration: 10964	Simtime (us): 250.86485530720887eta (-):	 0.871716693430576
# sigma (um):	 11.87720379991368
# tau (us):	 1.808009294030335
# Q0 (um-1):	 0.5728199065036158
# Iteration: 11392	Simtime (us): 300.09155625305544
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7466	Simtime (us): 300.02018611796677
# Iteration: 8874	Simtime (us): 300.02097309262398
# Iteration: 9980	Simtime (us): 300.10902844675326
# Iteration: 11392	Simtime (us): 300.09137732647304
# eta (-):	 0.8701925509423318
# sigma (um):	 11.877677875055817
# tau (us):	 1.8221932295667411
# Q0 (um-1):	 0.5755959703465178
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7530	Simtime (us): 300.13510357321974
# Iteration: 8453	Simtime (us): 300.15835478827626
# Iteration: 10035	Simtime (us): 300.13792290448384
# Iteration: 11428	Simtime (us): 300.05290187863663
# eta (-):	 0.8713339330566093
# sigma (um):	 11.877316522914695
# tau (us):	 1.8115443589300864
# Q0 (um-1):	 0.5735198930063979
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7552	Simtime (us): 300.19813831389416
# Iteration: 8888	Simtime (us): 300.15682094544465
# Iteration: 9996	Simtime (us): 300.05040877641297
# Iteration: 11417	Simtime (us): 299.35978855593646eta (-):	 0.8716209241367368
# sigma (um):	 11.877231711308056
# tau (us):	 1.8088925481478435
# Q0 (um-1):	 0.5729951708827512
# Iteration: 11423	Simtime (us): 300.12213485130167
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7544	Simtime (us): 300.20109923885843
# Iteration: 8846	Simtime (us): 300.16233570868167
# Iteration: 9979	Simtime (us): 300.12418935349757
# Iteration: 11102	Simtime (us): 263.62857876167595eta (-):	 0.8716927464814344
# sigma (um):	 11.877210761993311
# tau (us):	 1.808230077526231
# Q0 (um-1):	 0.5728637277626104
# Iteration: 11410	Simtime (us): 300.03303939351156
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 7522	Simtime (us): 300.06147476174546
# Iteration: 8875	Simtime (us): 300.11480988316544
# Iteration: 9982	Simtime (us): 300.04000775266644
# Iteration: 10412	Simtime (us): 200.42785349147743eta (-):	 0.8717107064089068
# sigma (um):	 11.877205539463578
# tau (us):	 1.8080644880560603
# Q0 (um-1):	 0.5728308516477907
# Iteration: 11389	Simtime (us): 300.00721828092446
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6442	Simtime (us): 300.18539212906277
# Iteration: 8875	Simtime (us): 300.17365783380524
# Iteration: 9981	Simtime (us): 300.13779925356942
# Iteration: 11361	Simtime (us): 300.02235451032114
# eta (-):	 0.871710721310068
# sigma (um):	 11.877205539463578
# tau (us):	 1.8080644880560603
# Q0 (um-1):	 0.5728308516477907
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6443	Simtime (us): 300.02836503073827
# Iteration: 8875	Simtime (us): 300.17366564901254
# Iteration: 9981	Simtime (us): 300.13782136098434
# Iteration: 10559	Simtime (us): 215.16974505880577eta (-):	 0.8717107064089068
# sigma (um):	 11.877205716447731
# tau (us):	 1.8080644880560603
# Q0 (um-1):	 0.5728308516477907
# Iteration: 11361	Simtime (us): 300.02087671388193
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6441	Simtime (us): 300.22968993769096
# Iteration: 8875	Simtime (us): 300.17365580690813
# Iteration: 9981	Simtime (us): 300.13778729854357
# Iteration: 10815	Simtime (us): 238.90587254006166eta (-):	 0.8717107064089068
# sigma (um):	 11.877205539463578
# tau (us):	 1.8080645149983208
# Q0 (um-1):	 0.5728308516477907
# Iteration: 11361	Simtime (us): 300.02332510780894
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6439	Simtime (us): 300.13030346941167
# Iteration: 8875	Simtime (us): 300.17364708004324
# Iteration: 9981	Simtime (us): 300.13775972207117
# Iteration: 11361	Simtime (us): 300.02558904491147
# eta (-):	 0.8717107064089068
# sigma (um):	 11.877205539463578
# tau (us):	 1.8080644880560603
# Q0 (um-1):	 0.5728308665489519
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6439	Simtime (us): 300.06662968350943
# Iteration: 8875	Simtime (us): 300.17364590922756
# Iteration: 9981	Simtime (us): 300.13776547496144
# Iteration: 10756	Simtime (us): 233.19152559194012eta (-):	 0.8717100077505882
# sigma (um):	 11.877202089809114
# tau (us):	 1.808003575420214
# Q0 (um-1):	 0.572871850922026
# Iteration: 11361	Simtime (us): 300.02461602204186
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 4979	Simtime (us): 300.17310904674056
# Iteration: 8875	Simtime (us): 300.16483726703945
# Iteration: 9981	Simtime (us): 300.13346179396532
# Iteration: 10811	Simtime (us): 237.81705462915191eta (-):	 0.8717100737363993
# sigma (um):	 11.877204786492724
# tau (us):	 1.808052913572462
# Q0 (um-1):	 0.5728416516709708
# Iteration: 11368	Simtime (us): 300.00702652623875
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 4999	Simtime (us): 300.14693122276447
# Iteration: 8875	Simtime (us): 300.16933049117722
# Iteration: 9981	Simtime (us): 300.12945101308752
# Iteration: 11359	Simtime (us): 300.08662034504846
# eta (-):	 0.8717101600806291
# sigma (um):	 11.877205492262497
# tau (us):	 1.808066097444645
# Q0 (um-1):	 0.5728336245974623
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 5007	Simtime (us): 300.17692331856025
# Iteration: 8875	Simtime (us): 300.17053719905164
# Iteration: 9981	Simtime (us): 300.12842704866514
# Iteration: 10857	Simtime (us): 243.64103173528357eta (-):	 0.8717105132011483
# sigma (um):	 11.877205581682377
# tau (us):	 1.8080662043871776
# Q0 (um-1):	 0.5728311959515272
# Iteration: 11356	Simtime (us): 300.11304701190045
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6124	Simtime (us): 300.14028788773897
# Iteration: 8875	Simtime (us): 300.17259935288683
# Iteration: 9981	Simtime (us): 300.13422395343423
# Iteration: 11038	Simtime (us): 262.21087488140216eta (-):	 0.8717105281023095
# sigma (um):	 11.877205581682377
# tau (us):	 1.8080662043871776
# Q0 (um-1):	 0.5728311959515272
# Iteration: 11359	Simtime (us): 300.05395428880047
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6126	Simtime (us): 300.01327843180445
# Iteration: 8875	Simtime (us): 300.17260712023756
# Iteration: 9981	Simtime (us): 300.13424591068599
# Iteration: 10589	Simtime (us): 218.01195873854942eta (-):	 0.8717105132011483
# sigma (um):	 11.877205758666532
# tau (us):	 1.8080662043871776
# Q0 (um-1):	 0.5728311959515272
# Iteration: 11359	Simtime (us): 300.05236040158015
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6122	Simtime (us): 300.09451940681724
# Iteration: 8875	Simtime (us): 300.17259735927155
# Iteration: 9981	Simtime (us): 300.13421210009194
# Iteration: 10861	Simtime (us): 243.69556601056084eta (-):	 0.8717105132011483
# sigma (um):	 11.877205581682377
# tau (us):	 1.8080662313294635
# Q0 (um-1):	 0.5728311959515272
# Iteration: 11359	Simtime (us): 300.05500094144993
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6120	Simtime (us): 300.20458972064574
# Iteration: 8875	Simtime (us): 300.17258868700914
# Iteration: 9981	Simtime (us): 300.13418471872706
# Iteration: 10594	Simtime (us): 218.45984192793676eta (-):	 0.8717105132011483
# sigma (um):	 11.877205581682377
# tau (us):	 1.8080662043871776
# Q0 (um-1):	 0.5728312108526884
# Iteration: 11359	Simtime (us): 300.05744261112864
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6120	Simtime (us): 300.10662340238673
# Iteration: 8875	Simtime (us): 300.17258750145766
# Iteration: 9981	Simtime (us): 300.13419040436924
# Iteration: 10773	Simtime (us): 235.03943840850448eta (-):	 0.8717117900080094
# sigma (um):	 11.877205536882478
# tau (us):	 1.808067440714645
# Q0 (um-1):	 0.5728312910310737
# Iteration: 11359	Simtime (us): 300.05639349043245
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6121	Simtime (us): 300.16117993881097
# Iteration: 8875	Simtime (us): 300.17270031993974
# Iteration: 9981	Simtime (us): 300.134093867771878
# Iteration: 10508	Simtime (us): 210.97580390594828eta (-):	 0.8717108301020664
# sigma (um):	 11.877205570827984
# tau (us):	 1.8080665326933765
# Q0 (um-1):	 0.572831223701858
# Iteration: 11359	Simtime (us): 300.09211460525586
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6119	Simtime (us): 300.19959135683187
# Iteration: 8875	Simtime (us): 300.17261261458912
# Iteration: 9981	Simtime (us): 300.13415105082953
# Iteration: 11359	Simtime (us): 300.06631379271167
# eta (-):	 0.8717105897196107
# sigma (um):	 11.877205579457634
# tau (us):	 1.8080663053434394
# Q0 (um-1):	 0.5728312067352167
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6118	Simtime (us): 300.08234115734357
# Iteration: 8875	Simtime (us): 300.17259071907474
# Iteration: 9981	Simtime (us): 300.13416555382327
# Iteration: 11359	Simtime (us): 300.06059034647343
# eta (-):	 0.8717106046207719
# sigma (um):	 11.877205579457634
# tau (us):	 1.8080663053434394
# Q0 (um-1):	 0.5728312067352167
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6121	Simtime (us): 300.19595078821828
# Iteration: 8875	Simtime (us): 300.17259848560248
# Iteration: 9981	Simtime (us): 300.13418750820045
# Iteration: 11359	Simtime (us): 300.05899371605337
# eta (-):	 0.8717105897196107
# sigma (um):	 11.87720575644179
# tau (us):	 1.8080663053434394
# Q0 (um-1):	 0.5728312067352167
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 4149	Simtime (us): 15.639210149255929
# Iteration: 8875	Simtime (us): 300.17258872603166
# Iteration: 9981	Simtime (us): 300.134153702439488
# Iteration: 10791	Simtime (us): 236.78604694401074eta (-):	 0.8717105897196107
# sigma (um):	 11.877205579457634
# tau (us):	 1.8080663322857269
# Q0 (um-1):	 0.5728312067352167
# Iteration: 11359	Simtime (us): 300.06163879610533
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6114	Simtime (us): 300.15376730100743
# Iteration: 8875	Simtime (us): 300.17258005470893
# Iteration: 9981	Simtime (us): 300.13412632482675
# Iteration: 10392	Simtime (us): 201.26936208926568eta (-):	 0.8717105897196107
# sigma (um):	 11.877205579457634
# tau (us):	 1.8080663053434394
# Q0 (um-1):	 0.5728312216363779
# Iteration: 11359	Simtime (us): 300.06336138800987
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6114	Simtime (us): 300.05514280017417
# Iteration: 9056	Simtime (us): 187.22147176953084
# Iteration: 9981	Simtime (us): 300.13413200917615
# Iteration: 11297	Simtime (us): 292.28265779544915eta (-):	 0.8717105697780624
# sigma (um):	 11.877205585610486
# tau (us):	 1.8080662032455244
# Q0 (um-1):	 0.5728312501612387
# Iteration: 11359	Simtime (us): 300.06303374774427
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 0	Simtime (us): 0.001Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6120	Simtime (us): 300.21677114812957
# Iteration: 8875	Simtime (us): 300.17258613549898
# Iteration: 9981	Simtime (us): 300.13418666669145
# Iteration: 11359	Simtime (us): 300.05664865407624
# Done!

# %%
# Display parameters, standard deviation, and correlation coefficient
parameters = ['eta','sigma','tau','Q0']
print("Parameters:")
for name, param, std in zip(parameters,popt,np.sqrt(np.diag(pcov))):
    print(f"{name}:\t{param:.10f}\t+/-\t{std:.10f}")

print("\nCorrelation Coefficients:")
for i in range(len(popt)):
    for j in range(i+1, len(popt)):
        print(f"{parameters[i]} vs {parameters[j]}: {pcov[i,j]/np.prod(np.sqrt(pcov[i,i]*pcov[j,j])):.10f}")

#Output:
# Out:
# Parameters:
# eta:	0.8717105897	+/-	0.0011412553
# sigma:	11.8772055795	+/-	0.0463442580
# tau:	1.8080663053	+/-	0.0005310352
# Q0:	0.5728312067	+/-	0.0011352580
#
# Correlation Coefficients:
# eta vs sigma: 0.9930489124
# eta vs tau: -0.0538458676
# eta vs Q0: -0.9312592990
# sigma vs tau: -0.0364483773
# sigma vs Q0: -0.9519198271
# tau vs Q0: -0.2619724916

# %%
simdata = plotsim(popt[0],popt[1],popt[2],popt[3])
# Out:
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Warning! When using a trickle_time, sigma_IC must be small enough compared to absorber length. Otherwise qps are 'lost' outside the borders of the domain.
# Iteration: 6118	Simtime (us): 300.08234115734352
# Iteration: 8875	Simtime (us): 300.17259071907476
# Iteration: 9981	Simtime (us): 300.13416555382327
# Iteration: 11359	Simtime (us): 300.06059034647343

# %%
lambdasinnm = [402,673,986,1545]
plt.figure()
for lambdanm in lambdasinnm:
    phase = KIDdict[lambdanm].phase
    t = KIDdict[lambdanm].t_full
    t -= t[np.argmax(phase)]
    plt.plot(simdata[lambdanm].t_axis_interp,simdata[lambdanm].phaseintime,alpha=0.5)
    plt.scatter(t,phase,marker='.',s=10)
plt.xlim(10*simdata[lambdanm].t_start,50)
plt.ylim(1e-3)
plt.xlabel(r'time ($\mu s$)')
plt.ylabel(r'$\theta$ (rad)')
#plt.semilogy()
plt.show()
plt.figure()
for lambdanm in lambdasinnm:
    phase = KIDdict[lambdanm].phase
    t = KIDdict[lambdanm].t_full
    t -= t[np.argmax(phase)]
    plt.plot(simdata[lambdanm].t_axis_interp,simdata[lambdanm].phaseintime*lambdanm,alpha=0.5)
    plt.scatter(t,phase*lambdanm,marker='.',s=10)
plt.xlim(10*simdata[lambdanm].t_start,50)
plt.ylim(1e-4)
plt.xlabel(r'time ($\mu s$)')
plt.ylabel(r'$\theta\cdot\lambda_{ph}$ (rad$\cdot nm$)')
#plt.semilogy()
plt.show()
