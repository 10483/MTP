# %%
from sympy import *
init_printing(use_latex="mathjax")

# %%
x,k,x0=symbols('x,k,x0', real=True)
D,epsilon,R,Q0,A,t0,t,N_qp0,sigma=symbols('D,epsilon,R,Q0,A,t0,t,N_qp0,sigma', real=True, positive=True)

N=Function('N')(x,t)
P=Function('P')(x,t)
P2=Function('P2')(x,t)
P3=Function('P3')(x,t)
P4=Function('P4')(x,t)

A=Function('A')(x)


Q=N+epsilon*P+epsilon**2*P2+epsilon**3*P3+epsilon**4*P4

# %%
PDE_long = diff(Q,t)-epsilon*D*diff(Q,x,2)+R*Q**2+2*R*Q0*Q
collect(PDE_long.expand(),epsilon)
# Out:
#
#                     8   2              7                        2          6 ⎛
# 2⋅Q₀⋅R⋅N(x, t) + R⋅ε ⋅P₄ (x, t) + 2⋅R⋅ε ⋅P₃(x, t)⋅P₄(x, t) + R⋅N (x, t) + ε ⋅⎝
#
#
#
#                                           ⎛      2
#                             2      ⎞    5 ⎜     ∂
# 2⋅R⋅P₂(x, t)⋅P₄(x, t) + R⋅P₃ (x, t)⎠ + ε ⋅⎜- D⋅───(P₄(x, t)) + 2⋅R⋅P(x, t)⋅P₄(
#                                           ⎜      2
#                                           ⎝    ∂x
#
#                              ⎞      ⎛      2
#                              ⎟    4 ⎜     ∂
# x, t) + 2⋅R⋅P₂(x, t)⋅P₃(x, t)⎟ + ε ⋅⎜- D⋅───(P₃(x, t)) + 2⋅Q₀⋅R⋅P₄(x, t) + 2⋅R
#                              ⎟      ⎜      2
#                              ⎠      ⎝    ∂x
#
#                                                                      ⎞      ⎛
#                                                2         ∂           ⎟    3 ⎜
# ⋅N(x, t)⋅P₄(x, t) + 2⋅R⋅P(x, t)⋅P₃(x, t) + R⋅P₂ (x, t) + ──(P₄(x, t))⎟ + ε ⋅⎜-
# ...

# %%
N=2*Q0/((2*Q0/A+1)*exp(2*Q0*R*t)-1)
N=N.simplify()
N
# Out:
# <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default'></script>
#           2⋅Q₀⋅A(x)
# ──────────────────────────────
#                2⋅Q₀⋅R⋅t
# (2⋅Q₀ + A(x))⋅ℯ         - A(x)

# %%
N_int = integrate(N,(t,0,t))
N_int.simplify()
# Out:
# <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default'></script>
#                                   ⎛               2⋅Q₀⋅R⋅t       ⎞
#                ⎛    2⋅Q₀   ⎞      ⎜(2⋅Q₀ + A(x))⋅ℯ         - A(x)⎟
# -2⋅Q₀⋅R⋅t - log⎜───────────⎟ + log⎜──────────────────────────────⎟
#                ⎝2⋅Q₀ + A(x)⎠      ⎝         2⋅Q₀ + A(x)          ⎠
# ──────────────────────────────────────────────────────────────────
#                                 R

# %%
N_int = (-2*Q0*R*t + log((((2*Q0 + A)*exp(2*Q0*R*t) - A)/(2*Q0 + A)/(2*Q0/(2*Q0 + A)))))/R
N_int = N_int.simplify()
N_int
# Out:
# <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default'></script>
#                ⎛               2⋅Q₀⋅R⋅t       ⎞
#                ⎜(2⋅Q₀ + A(x))⋅ℯ         - A(x)⎟
# -2⋅Q₀⋅R⋅t + log⎜──────────────────────────────⎟
#                ⎝             2⋅Q₀             ⎠
# ───────────────────────────────────────────────
#                        R

# %%
A = N_qp0/(sigma*sqrt(2*pi)) * exp(-(x/sigma)**2/2)
N=2*Q0/((2*Q0/A+1)*exp(2*Q0*R*t)-1)
N=N.simplify()
N
print(diff(N,x,2).simplify())
# Out:
# -4*N_qp0*Q0**2*(8*pi*Q0*sigma*x**2*exp((2*Q0*R*sigma**2*t + x**2)/sigma**2) + sqrt(2)*sqrt(pi)*sigma**2*(N_qp0 - (N_qp0 + 2*sqrt(2)*sqrt(pi)*Q0*sigma*exp(x**2/(2*sigma**2)))*exp(2*Q0*R*t))*exp(x**2/(2*sigma**2)) + sqrt(2)*sqrt(pi)*x**2*(N_qp0 - (N_qp0 + 2*sqrt(2)*sqrt(pi)*Q0*sigma*exp(x**2/(2*sigma**2)))*exp(2*Q0*R*t))*exp(x**2/(2*sigma**2)))*exp(2*Q0*R*t)/(sigma**3*(N_qp0 - (N_qp0 + 2*sqrt(2)*sqrt(pi)*Q0*sigma*exp(x**2/(2*sigma**2)))*exp(2*Q0*R*t))**3)

# %%
particular = D*exp(-2*R*(Q0*t+N_int))*integrate(diff(N,x,2)*exp(2*R*(Q0*t+N_int)),(t,0,t))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-743c3d57978c> in <cell line: 1>()
# ----> 1 particular = D*exp(-2*R*(Q0*t+N_int))*integrate(diff(N,x,2)*exp(2*R*(Q0*t+N_int)),(t,0,t))
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/integrals.py in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1565
#    1566     if isinstance(integral, Integral):
# -> 1567         return integral.doit(**doit_flags)
#    1568     else:
#    1569         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     610                     antideriv = None
#     611                 else:
# --> 612                     antideriv = self._eval_integral(
#     613                         function, xab[0], **eval_kwargs)
# ...
