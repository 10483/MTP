# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from Finite_volume_method_1D import *

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Computer Modern",
    "figure.dpi": 200,
})

# %%
data_list = []
sim_list = []
comp_list = []
sigmas = np.linspace(0.5,5,10)
for sigma in sigmas:
    chippath = '../../DataKian/Al_LT165chip7/'
    Al_data = KID_data(chippath,
                    lambda_ph_in_nm=673,
                    KIDno=2,
                    readout_power=89,
                    temp_in_mK=120,
                    width=10,
                    length=310,
                    T_eff=0.225,
                    N0=172e8,
                    sigma_IC=sigma,
                    D=15000)
    Al_data.fit_tail(start=500,showplots=False)
    Al_sim = KID_sim(Al_data,0.0005,sigma/4,10,method='CrankNicolson',adaptivedx=True)
    data_list.append(Al_data)
    sim_list.append(Al_sim)
    comp_list.append(sim_data_comp(Al_data,Al_sim))
# Out:
# 100%|██████████| 20000/20000 [00:23<00:00, 858.04it/s]
# 100%|██████████| 20000/20000 [00:21<00:00, 916.84it/s]
# 100%|██████████| 20000/20000 [00:19<00:00, 1001.89it/s]
# 100%|██████████| 20000/20000 [00:19<00:00, 1040.07it/s]
# 100%|██████████| 20000/20000 [00:19<00:00, 1003.63it/s]
# 100%|██████████| 20000/20000 [00:18<00:00, 1064.49it/s]
# 100%|██████████| 20000/20000 [00:21<00:00, 936.08it/s]
# 100%|██████████| 20000/20000 [00:22<00:00, 878.28it/s]
# 100%|██████████| 20000/20000 [00:20<00:00, 969.86it/s]
# 100%|██████████| 20000/20000 [00:22<00:00, 894.77it/s]

# %%
data_list2 = []
sim_list2 = []
comp_list2 = []
for sigma in sigmas:
    chippath = '../../DataKian/bTa_LT278W2chip5/'
    bTa_data = KID_data(chippath,
                        lambda_ph_in_nm=673,
                        KIDno=3,
                        readout_power=96,
                        temp_in_mK=140,
                        width=10,
                        length=90,
                        T_eff=0.100,
                        N0=303e8,
                        sigma_IC=sigma,
                        D=50)
    bTa_data.fit_tail(start=160,end=300,showplots=False)
    bTa_sim = KID_sim(bTa_data,0.0005,sigma/4,10,method='CrankNicolson',adaptivedx=True)
    data_list2.append(bTa_data)
    sim_list2.append(bTa_sim)
    comp_list2.append(sim_data_comp(bTa_data,bTa_sim))
# Out:
# 100%|██████████| 20000/20000 [00:34<00:00, 579.11it/s]
# 100%|██████████| 20000/20000 [00:54<00:00, 363.83it/s]
# 100%|██████████| 20000/20000 [00:47<00:00, 420.49it/s]
# 100%|██████████| 20000/20000 [00:42<00:00, 475.10it/s]
# 100%|██████████| 20000/20000 [00:50<00:00, 397.84it/s]
# 100%|██████████| 20000/20000 [00:59<00:00, 335.39it/s]
# 100%|██████████| 20000/20000 [00:52<00:00, 380.00it/s]
# 100%|██████████| 20000/20000 [00:43<00:00, 458.74it/s]
# 100%|██████████| 20000/20000 [00:42<00:00, 469.16it/s]
# 100%|██████████| 20000/20000 [00:47<00:00, 416.74it/s]

# %%
plt.figure()
for sigma,data,comp in zip(sigmas,data_list,comp_list):
    label = r'$\sigma_{IC} = $'+str(round(sigma,2))+r'$\mu m$'
    alpha = np.max([0.05,(sigma-np.min(sigmas))/(np.max(sigmas)-np.min(sigmas))])
    plt.semilogy(comp.t_sim_aligned,comp.phasesim,color='r',alpha=alpha,label=label)
plt.semilogy(data.t_full,data.phase)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
