# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from Finite_volume_method_1D import *

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Computer Modern",
    "figure.dpi": 200,
})

# %%
data_list = []
sim_list = []
comp_list = []
dxs = np.linspace(0.25,5,20)
for dx in dxs:
    chippath = '../../DataKian/Al_LT165chip7/'
    Al_data = KID_data(chippath,
                    lambda_ph_in_nm=673,
                    KIDno=2,
                    readout_power=89,
                    temp_in_mK=120,
                    width=10,
                    length=310,
                    T_eff=0.225,
                    N0=172e8,
                    sigma_IC=dx,
                    D=15000)
    Al_data.fit_tail(start=500,showplots=False)
    Al_sim = KID_sim(Al_data,dx/10,dx,100,method='CrankNicolson',ring=True,gaussianIC=False)
    data_list.append(Al_data)
    sim_list.append(Al_sim)
    comp_list.append(sim_data_comp(Al_data,Al_sim))
# Out:
#   1%|▏         | 56/4000 [00:30<44:51,  1.47it/s]

# %%
data_list2 = []
sim_list2 = []
comp_list2 = []
for dx in dxs:
    chippath = '../../DataKian/bTa_LT278W2chip5/'
    bTa_data = KID_data(chippath,
                        lambda_ph_in_nm=673,
                        KIDno=3,
                        readout_power=96,
                        temp_in_mK=140,
                        width=10,
                        length=90,
                        T_eff=0.100,
                        N0=303e8,
                        sigma_IC=dx,
                        D=50)
    bTa_data.fit_tail(start=160,end=300,showplots=False)
    bTa_sim = KID_sim(bTa_data,dx/5,dx,100,method='CrankNicolson',ring=True,gaussianIC=False)
    data_list2.append(bTa_data)
    sim_list2.append(bTa_sim)
    comp_list2.append(sim_data_comp(bTa_data,bTa_sim))

# %%
plt.figure()
for dx,data,comp in zip(dxs,data_list,comp_list):
    label = r'$\sigma_{IC} = $'+str(round(dx,2))+r'$\mu m$'
    alpha = np.max([0.05,(dx-np.min(dxs))/(np.max(dxs)-np.min(dxs))])
    plt.semilogy(comp.t_sim_aligned,comp.phasesim,color='r',alpha=alpha,label=label)
plt.semilogy(data.t_full,data.phase)
plt.legend()
plt.show()
